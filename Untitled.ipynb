# %%
from supabase import create_client, Client
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/romanshemet/miniconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/romanshemet/miniconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
# ...

# %%
supabase: Client = create_client(
    'https://vlqqczxwyaodtcdmdmlw.supabase.co', 
    'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InZscXFjenh3eWFvZHRjZG1kbWx3Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTE1MTg2MzIsImV4cCI6MjA2NzA5NDYzMn0.nBzqGuK9j6RZ6mOPWU2boAC_5H9XDs-fPpo5P3WZYbI'
)

# %%
def run_sql_snippet(snippet_name: str, params: dict = None):
    """Runs a SQL snippet from Supabase."""
    try:
        # Supabase Python library uses RPC to call PostgreSQL functions
        if params:
            data = supabase.rpc(snippet_name, params).execute()
        else:
            data = supabase.rpc(snippet_name, {}).execute()
        
        return pd.DataFrame(data.data)
    except Exception as e:
        print(f"Error running snippet '{snippet_name}': {e}")

# %%
df = run_sql_snippet('get_generated_tokens_new')

# %%
df
# Out:
#              t     framework               device  tokens_generated
# 0   2025-07-12  react-native        iOS Simulator              7012
# 1   2025-07-13  react-native        iOS Simulator              3016
# 2   2025-07-11  react-native        iOS Simulator              1457
# 3   2025-07-13  react-native           iPhone17,3              1416
# 4   2025-07-13       flutter   sdk_gphone64_arm64              1376
# 5   2025-07-13       flutter     Redmi Note 9 Pro              1368
# 6   2025-07-13  react-native           iPhone14,5               901
# 7   2025-07-12       flutter           iPhone17,4               646
# 8   2025-07-12       flutter           iPhone16,1               599
# 9   2025-07-14       flutter           iPhone16,1               579
# 10  2025-07-12       flutter             SM-G991B               275
# 11  2025-07-14       flutter           iPhone17,4               261
# 12  2025-07-13       flutter           iPhone17,1               218
# ...

# %%
df1 = df.groupby(['device', 't'])[['tokens_generated']].sum().reset_index()
df1['cum'] = df1.groupby('device')['tokens_generated'].cumsum()

df1.plot()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/romanshemet/miniconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/romanshemet/miniconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
# ...
